# %%
import json
import pandas as pd
import numpy as np
import glob
import csv
import datetime
from sqlalchemy import create_engine
import psycopg2
from config import db_password
import time

# %%
predicted_df = pd.read_csv('https://gentrificationoutcome.s3.amazonaws.com/predicted.csv')
predicted_df.set_index('zip', inplace=True)
predicted_df.head()
# Out:
#        Index Change  Percent_Change_House  Percent_Change_Rent  \
# zip
# 91311          0.28              0.418051             0.592135
# 90670          0.78              0.492026             0.699865
# 92065         -0.10              0.400943             0.728412
# 93710          0.07              0.332705             0.561279
# 95019          0.94              0.561080             0.627803
#
#        Percent_Change_Income  Percent_Change_Public_Transp  \
# zip
# 91311               0.289208                         0.011
# 90670               0.127527                         0.012
# 92065               0.280726                        -0.004
# 93710               0.272468                         0.014
# 95019               0.002944                         0.006
#
#        Percent_Change_Population  Percent_Change_White  Outcome
# zip
# 91311                   0.069428                -0.102        0
# 90670                  -0.041136                 0.075        0
# 92065                   0.089219                 0.030        0
# 93710                   0.129130                -0.023        0
# 95019                   0.557668                 0.218        0

# %%
california_df =pd.read_csv('https://gentrificationmldata.s3.amazonaws.com/california_blank_tagged.csv')
california_df.set_index('zip', inplace=True)
california_df.head()
# Out:
#        median_house_value_2000  median_house_value_2014  percent_change_house  \
# zip
# 90001                   138900                   241800              0.740821
# 90002                   127700                   218800              0.713391
# 90003                   134400                   228600              0.700893
# 90004                   371100                   724900              0.953382
# 90005                   392200                   635500              0.620347
#
#        median_income_2000  median_income_2014  percent_change_income  \
# zip
# 90001               24207               34050                   0.41
# 90002               22872               30214                   0.32
# 90003               22346               30016                   0.34
# 90004               27591               38493                   0.40
# 90005               21998               31214                   0.42
#
#        median_rent_2000  median_rent_2014  percent_change_rent  \
# zip
# 90001               568               975                0.717
# 90002               560               968                0.729
# 90003               572              1064                0.860
# 90004               600              1070                0.783
# 90005               547               939                0.717
#
#        average_education_index_2000  ...  percent_public_transp_2000  \
# zip                                  ...
# 90001                          9.49  ...                       0.172
# 90002                         10.06  ...                       0.123
# 90003                          9.91  ...                       0.173
# 90004                         11.83  ...                       0.216
# 90005                         11.37  ...                       0.342
#
#        percent_public_transp_2014  percent_change_public_tranp  \
# zip
# 90001                       0.167                    -0.029070
# 90002                       0.137                     0.113821
# 90003                       0.175                     0.011561
# 90004                       0.231                     0.069444
# 90005                       0.351                     0.026316
#
#        population_2000  population_2014  percent_change_population  \
# zip
# 90001            54481            56314                      0.034
# 90002            44584            50098                      0.124
# 90003            58187            66913                      0.150
# 90004            67850            63547                     -0.063
# 90005            43014            38638                     -0.102
#
#        percent_white_2000  percent_white_2014  percent_change_white  Outcome
# zip
# 90001               0.246               0.499                 1.028        0
# 90002               0.166               0.484                 1.916        0
# 90003               0.193               0.224                 0.161        0
# 90004               0.338               0.345                 0.021        0
# 90005               0.278               0.196                -0.295        0
#
# [5 rows x 22 columns]

# %%
predicted_df.count()
# Out:
# Index Change                    273
# Percent_Change_House            273
# Percent_Change_Rent             273
# Percent_Change_Income           273
# Percent_Change_Public_Transp    273
# Percent_Change_Population       273
# Percent_Change_White            273
# Outcome                         273
# dtype: int64

# %%
predicted_df.to_csv('Resources/predicted.csv', index='zip', header=True)
