# %%
import json
import pandas as pd
import numpy as np
import glob
import csv
from faker import Faker
from faker.providers import internet
import datetime
from sqlalchemy import create_engine
import psycopg2
from config import db_password
import time

# %%
predicted_df = pd.read_csv('https://gentrificationoutcome.s3.amazonaws.com/predicted.csv ')
predicted_df.head()
# Out:
#      zip  Index Change  Percent_Change_House  Percent_Change_Rent  \
# 0  91311          0.28              0.418051             0.592135
# 1  90670          0.78              0.492026             0.699865
# 2  92065         -0.10              0.400943             0.728412
# 3  93710          0.07              0.332705             0.561279
# 4  95019          0.94              0.561080             0.627803
#
#    Percent_Change_Public_Transp  Percent_Change_Population  \
# 0                         0.011                   0.069428
# 1                         0.012                  -0.041136
# 2                        -0.004                   0.089219
# 3                         0.014                   0.129130
# 4                         0.006                   0.557668
#
#    Percent_Change_White  Outcome
# 0                -0.102        0
# 1                 0.075        0
# 2                 0.030        0
# 3                -0.023        0
# 4                 0.218        0

# %%
predicted_df.to_csv('Resources/predicted.csv', index='zip', header=True)
